# %%
# ### INSTALL PACKAGES

# !pip install opencv-python

# sudo apt-get update
# sudo apt-get install build-essential cmake
# sudo apt-get install libopenblas-dev liblapack-dev 
# sudo apt-get install libx11-dev libgtk-3-dev
# pip install face_recognition

TypeError: compute_face_descriptor(): incompatible function arguments. The following argument types are supported:

# %%
import cv2
import numpy as np
import face_recognition as fr

# %%
video_capture = cv2.VideoCapture(0) # 0 is the default camera

# %%
image = fr.load_image_file("data/bosslady.jpeg")

# %%
image_face_encoding = fr.face_encodings(image)[0] # Get the face encoding of the image

# %%
known_face_encodings = [image_face_encoding]

# %%
known_face_names = ["Bosslady"]

# %%
while True:

    ret, frame = video_capture.read()
    rgb_frame = frame[:, :, ::-1]  # Convert BGR to RGB

    fc_locations = fr.face_locations(rgb_frame)
    fc_encodings = fr.face_encodings(rgb_frame, fc_locations)

    for (top, right, bottom, left), face_encoding in zip(fc_locations, fc_encodings):
        matches = fr.compare_faces(known_face_encodings, face_encoding)
        name = "Unknown"

        fc_distances = fr.face_distance(known_face_encodings, face_encoding)
        match_index = np.argmin(fc_distances)

        if matches[match_index]:
            name = known_face_names[match_index]

        cv2.rectangle(frame, (left, top), (right, bottom), (0, 0, 255), 2)
        cv2.rectangle(frame, (left, bottom - 35), (right, bottom), (0, 0, 255), cv2.FILLED)
        
        font = cv2.FONT_HERSHEY_DUPLEX
        
        cv2.putText(frame, name, (left + 6, bottom - 6), font, 1.0, (255, 255, 255), 1)

    cv2.imshow('Face detection system', frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

video_capture.release()
cv2.destroyAllWindows()

# %%
ord('A')
#help(ord)
65%26

chr(65)
# Out:
# 'A'

# %%
import cv2
import numpy as np

# Simple détection de visages sans reconnaissance
def simple_face_detection():
    # Charger le classificateur Haar
    face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
    
    # Initialiser la capture vidéo
    cap = cv2.VideoCapture(0)
    
    if not cap.isOpened():
        print("Erreur: Impossible d'ouvrir la caméra")
        return
    
    print("Détection de visages démarrée. Appuyez sur 'q' pour quitter.")
    
    while True:
        ret, frame = cap.read()
        
        if not ret:
            break
        
        # Convertir en niveaux de gris
        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        
        # Détecter les visages
        faces = face_cascade.detectMultiScale(
            gray,
            scaleFactor=1.1,
            minNeighbors=5,
            minSize=(30, 30),
            flags=cv2.CASCADE_SCALE_IMAGE
        )
        
        # Dessiner des rectangles autour des visages
        for (x, y, w, h) in faces:
            cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 255, 0), 2)
            cv2.putText(frame, "Visage detecte", (x, y-10), 
                       cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)
        
        # Afficher le nombre de visages détectés
        cv2.putText(frame, f"Visages: {len(faces)}", (10, 30), 
                   cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 0), 2)
        
        # Afficher la frame
        cv2.imshow('Detection de Visages', frame)
        
        # Quitter avec 'q'
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
    
    # Libérer les ressources
    cap.release()
    cv2.destroyAllWindows()

if __name__ == "__main__":
    simple_face_detection()
# Out:
# Détection de visages démarrée. Appuyez sur 'q' pour quitter.
# qt.qpa.plugin: Could not find the Qt platform plugin "wayland" in "/home/bosslady/Virtual_env/AI-ML_env/lib/python3.12/site-packages/cv2/qt/plugins"
# QObject::moveToThread: Current thread (0x1d3ca770) is not the object's thread (0x1cf68740).
# Cannot move to target thread (0x1d3ca770)
#
# QObject::moveToThread: Current thread (0x1d3ca770) is not the object's thread (0x1cf68740).
# Cannot move to target thread (0x1d3ca770)
#
# QObject::moveToThread: Current thread (0x1d3ca770) is not the object's thread (0x1cf68740).
# Cannot move to target thread (0x1d3ca770)
#
# QObject::moveToThread: Current thread (0x1d3ca770) is not the object's thread (0x1cf68740).
# Cannot move to target thread (0x1d3ca770)
#
# QObject::moveToThread: Current thread (0x1d3ca770) is not the object's thread (0x1cf68740).
# Cannot move to target thread (0x1d3ca770)
#
# ...
